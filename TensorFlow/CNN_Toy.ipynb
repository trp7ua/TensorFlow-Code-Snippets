# %%
'''
A Convolutional Network implementation example using TensorFlow library.
This example is using the MNIST database of handwritten digits
(http://yann.lecun.com/exdb/mnist/)

Author: Aymeric Damien
Project: https://github.com/aymericdamien/TensorFlow-Examples/
'''

from __future__ import print_function

import tensorflow as tf

# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)


# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: mnist.test.images[:256],
                                      y: mnist.test.labels[:256],
                                      keep_prob: 1.}))
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Iter 1280, Minibatch Loss= 28408.654297, Training Accuracy= 0.32812
# Iter 2560, Minibatch Loss= 13977.827148, Training Accuracy= 0.42969
# Iter 3840, Minibatch Loss= 8855.958984, Training Accuracy= 0.62500
# Iter 5120, Minibatch Loss= 4673.686035, Training Accuracy= 0.73438
# Iter 6400, Minibatch Loss= 3343.580078, Training Accuracy= 0.75781
# Iter 7680, Minibatch Loss= 5082.595703, Training Accuracy= 0.72656
# Iter 8960, Minibatch Loss= 2975.646729, Training Accuracy= 0.78906
# Iter 10240, Minibatch Loss= 2442.363281, Training Accuracy= 0.88281
# Iter 11520, Minibatch Loss= 1740.400391, Training Accuracy= 0.89844
# Iter 12800, Minibatch Loss= 3746.482666, Training Accuracy= 0.77344
# Iter 14080, Minibatch Loss= 1343.450195, Training Accuracy= 0.91406
# Iter 15360, Minibatch Loss= 1215.182129, Training Accuracy= 0.90625
# Iter 16640, Minibatch Loss= 2113.510742, Training Accuracy= 0.85156
# Iter 17920, Minibatch Loss= 1324.294922, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 1096.135742, Training Accuracy= 0.90625
# Iter 20480, Minibatch Loss= 529.768921, Training Accuracy= 0.95312
# Iter 21760, Minibatch Loss= 2921.647461, Training Accuracy= 0.85156
# Iter 23040, Minibatch Loss= 489.916443, Training Accuracy= 0.93750
# Iter 24320, Minibatch Loss= 1881.040771, Training Accuracy= 0.86719
# Iter 25600, Minibatch Loss= 1338.835571, Training Accuracy= 0.92188
# Iter 26880, Minibatch Loss= 960.412842, Training Accuracy= 0.92969
# Iter 28160, Minibatch Loss= 1044.275391, Training Accuracy= 0.92969
# Iter 29440, Minibatch Loss= 1217.457642, Training Accuracy= 0.89844
# Iter 30720, Minibatch Loss= 919.401855, Training Accuracy= 0.89062
# Iter 32000, Minibatch Loss= 618.918457, Training Accuracy= 0.94531
# Iter 33280, Minibatch Loss= 892.769897, Training Accuracy= 0.92969
# Iter 34560, Minibatch Loss= 441.662598, Training Accuracy= 0.93750
# Iter 35840, Minibatch Loss= 360.561951, Training Accuracy= 0.96094
# Iter 37120, Minibatch Loss= 1571.500732, Training Accuracy= 0.89062
# Iter 38400, Minibatch Loss= 173.094101, Training Accuracy= 0.98438
# Iter 39680, Minibatch Loss= 130.410782, Training Accuracy= 0.96875
# Iter 40960, Minibatch Loss= 1750.002441, Training Accuracy= 0.89844
# Iter 42240, Minibatch Loss= 658.926758, Training Accuracy= 0.91406
# Iter 43520, Minibatch Loss= 217.899155, Training Accuracy= 0.96094
# Iter 44800, Minibatch Loss= 428.959076, Training Accuracy= 0.94531
# Iter 46080, Minibatch Loss= 288.461121, Training Accuracy= 0.97656
# Iter 47360, Minibatch Loss= 676.368652, Training Accuracy= 0.94531
# Iter 48640, Minibatch Loss= 1113.604980, Training Accuracy= 0.91406
# Iter 49920, Minibatch Loss= 823.466187, Training Accuracy= 0.89062
# Iter 51200, Minibatch Loss= 314.714478, Training Accuracy= 0.95312
# Iter 52480, Minibatch Loss= 131.747665, Training Accuracy= 0.96875
# Iter 53760, Minibatch Loss= 44.195236, Training Accuracy= 0.99219
# Iter 55040, Minibatch Loss= 1238.372192, Training Accuracy= 0.92969
# Iter 56320, Minibatch Loss= 521.380676, Training Accuracy= 0.92969
# Iter 57600, Minibatch Loss= 1055.458496, Training Accuracy= 0.91406
# Iter 58880, Minibatch Loss= 534.395264, Training Accuracy= 0.92188
# Iter 60160, Minibatch Loss= 641.634277, Training Accuracy= 0.94531
# Iter 61440, Minibatch Loss= 537.020386, Training Accuracy= 0.94531
# Iter 62720, Minibatch Loss= 1000.970581, Training Accuracy= 0.91406
# Iter 64000, Minibatch Loss= 184.699142, Training Accuracy= 0.96094
# Iter 65280, Minibatch Loss= 494.740143, Training Accuracy= 0.92969
# Iter 66560, Minibatch Loss= 755.879028, Training Accuracy= 0.96094
# Iter 67840, Minibatch Loss= 349.921417, Training Accuracy= 0.96875
# Iter 69120, Minibatch Loss= 34.405746, Training Accuracy= 0.98438
# Iter 70400, Minibatch Loss= 806.469116, Training Accuracy= 0.94531
# Iter 71680, Minibatch Loss= 605.670410, Training Accuracy= 0.92969
# Iter 72960, Minibatch Loss= 174.715714, Training Accuracy= 0.96875
# Iter 74240, Minibatch Loss= 610.271973, Training Accuracy= 0.93750
# Iter 75520, Minibatch Loss= 47.059128, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 447.274780, Training Accuracy= 0.96875
# Iter 78080, Minibatch Loss= 41.285774, Training Accuracy= 0.98438
# Iter 79360, Minibatch Loss= 559.316467, Training Accuracy= 0.94531
# Iter 80640, Minibatch Loss= 404.512695, Training Accuracy= 0.96875
# Iter 81920, Minibatch Loss= 630.567749, Training Accuracy= 0.94531
# Iter 83200, Minibatch Loss= 391.234894, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 261.277588, Training Accuracy= 0.96875
# Iter 85760, Minibatch Loss= 194.359787, Training Accuracy= 0.94531
# Iter 87040, Minibatch Loss= 505.539124, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 405.011566, Training Accuracy= 0.95312
# Iter 89600, Minibatch Loss= 364.932739, Training Accuracy= 0.98438
# Iter 90880, Minibatch Loss= 1243.787598, Training Accuracy= 0.89844
# Iter 92160, Minibatch Loss= 471.432831, Training Accuracy= 0.94531
# Iter 93440, Minibatch Loss= 131.885605, Training Accuracy= 0.97656
# Iter 94720, Minibatch Loss= 255.111008, Training Accuracy= 0.96875
# Iter 96000, Minibatch Loss= 424.721832, Training Accuracy= 0.94531
# Iter 97280, Minibatch Loss= 200.372665, Training Accuracy= 0.97656
# Iter 98560, Minibatch Loss= 39.297386, Training Accuracy= 0.98438
# Iter 99840, Minibatch Loss= 193.573090, Training Accuracy= 0.96094
# Iter 101120, Minibatch Loss= 534.358948, Training Accuracy= 0.95312
# Iter 102400, Minibatch Loss= 511.179077, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 243.378143, Training Accuracy= 0.96094
# Iter 104960, Minibatch Loss= 307.803406, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 648.248657, Training Accuracy= 0.95312
# Iter 107520, Minibatch Loss= 168.672485, Training Accuracy= 0.95312
# Iter 108800, Minibatch Loss= 346.376709, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 253.800858, Training Accuracy= 0.96094
# Iter 111360, Minibatch Loss= 209.304550, Training Accuracy= 0.93750
# Iter 112640, Minibatch Loss= 175.413300, Training Accuracy= 0.97656
# Iter 113920, Minibatch Loss= 381.749847, Training Accuracy= 0.96094
# Iter 115200, Minibatch Loss= 29.132607, Training Accuracy= 0.99219
# Iter 116480, Minibatch Loss= 192.678543, Training Accuracy= 0.96094
# Iter 117760, Minibatch Loss= 359.502380, Training Accuracy= 0.94531
# Iter 119040, Minibatch Loss= 653.950928, Training Accuracy= 0.90625
# Iter 120320, Minibatch Loss= 308.059998, Training Accuracy= 0.96094
# Iter 121600, Minibatch Loss= 307.580444, Training Accuracy= 0.95312
# Iter 122880, Minibatch Loss= 85.690750, Training Accuracy= 0.98438
# Iter 124160, Minibatch Loss= 74.416023, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 156.307358, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 412.084442, Training Accuracy= 0.96875
# Iter 128000, Minibatch Loss= 218.212189, Training Accuracy= 0.95312
# Iter 129280, Minibatch Loss= 334.198578, Training Accuracy= 0.95312
# Iter 130560, Minibatch Loss= 135.448334, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 319.687195, Training Accuracy= 0.96875
# Iter 133120, Minibatch Loss= 290.512604, Training Accuracy= 0.94531
# Iter 134400, Minibatch Loss= 186.113770, Training Accuracy= 0.97656
# Iter 135680, Minibatch Loss= 147.655930, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 215.510803, Training Accuracy= 0.96875
# Iter 138240, Minibatch Loss= 753.862061, Training Accuracy= 0.92969
# Iter 139520, Minibatch Loss= 353.294861, Training Accuracy= 0.95312
# Iter 140800, Minibatch Loss= 8.126633, Training Accuracy= 0.98438
# Iter 142080, Minibatch Loss= 298.735718, Training Accuracy= 0.93750
# Iter 143360, Minibatch Loss= 203.135712, Training Accuracy= 0.96094
# Iter 144640, Minibatch Loss= 152.220352, Training Accuracy= 0.96094
# Iter 145920, Minibatch Loss= 264.808380, Training Accuracy= 0.95312
# Iter 147200, Minibatch Loss= 144.060547, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 92.619919, Training Accuracy= 0.96875
# Iter 149760, Minibatch Loss= 71.380852, Training Accuracy= 0.97656
# Iter 151040, Minibatch Loss= 261.617126, Training Accuracy= 0.94531
# Iter 152320, Minibatch Loss= 149.911041, Training Accuracy= 0.97656
# Iter 153600, Minibatch Loss= 279.517059, Training Accuracy= 0.95312
# Iter 154880, Minibatch Loss= 150.318542, Training Accuracy= 0.96094
# Iter 156160, Minibatch Loss= 170.222290, Training Accuracy= 0.98438
# Iter 157440, Minibatch Loss= 224.861328, Training Accuracy= 0.95312
# Iter 158720, Minibatch Loss= 17.536423, Training Accuracy= 0.99219
# Iter 160000, Minibatch Loss= 60.392296, Training Accuracy= 0.98438
# Iter 161280, Minibatch Loss= 107.250145, Training Accuracy= 0.98438
# Iter 162560, Minibatch Loss= 120.764076, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 279.562103, Training Accuracy= 0.95312
# Iter 165120, Minibatch Loss= 170.597702, Training Accuracy= 0.95312
# Iter 166400, Minibatch Loss= 243.568069, Training Accuracy= 0.98438
# Iter 167680, Minibatch Loss= 83.096161, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 186.168503, Training Accuracy= 0.96875
# Iter 170240, Minibatch Loss= 137.008499, Training Accuracy= 0.96875
# Iter 171520, Minibatch Loss= 40.634369, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 185.034561, Training Accuracy= 0.95312
# Iter 174080, Minibatch Loss= 70.431259, Training Accuracy= 0.99219
# Iter 175360, Minibatch Loss= 19.912628, Training Accuracy= 0.99219
# Iter 176640, Minibatch Loss= 187.319611, Training Accuracy= 0.96875
# Iter 177920, Minibatch Loss= 422.213715, Training Accuracy= 0.92969
# Iter 179200, Minibatch Loss= 7.127655, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 198.125763, Training Accuracy= 0.96094
# Iter 181760, Minibatch Loss= 82.666641, Training Accuracy= 0.96875
# Iter 183040, Minibatch Loss= 101.934937, Training Accuracy= 0.96094
# Iter 184320, Minibatch Loss= 66.667191, Training Accuracy= 0.96875
# Iter 185600, Minibatch Loss= 45.988811, Training Accuracy= 0.97656
# Iter 186880, Minibatch Loss= 41.820595, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 347.110657, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 9.934158, Training Accuracy= 0.99219
# Iter 190720, Minibatch Loss= 230.274506, Training Accuracy= 0.96875
# Iter 192000, Minibatch Loss= 109.217789, Training Accuracy= 0.98438
# Iter 193280, Minibatch Loss= 17.757362, Training Accuracy= 0.97656
# Iter 194560, Minibatch Loss= 187.247864, Training Accuracy= 0.96875
# Iter 195840, Minibatch Loss= 187.832184, Training Accuracy= 0.98438
# Iter 197120, Minibatch Loss= 32.168602, Training Accuracy= 0.99219
# Iter 198400, Minibatch Loss= 264.437683, Training Accuracy= 0.96094
# Iter 199680, Minibatch Loss= 105.365623, Training Accuracy= 0.98438
# Optimization Finished!
# Testing Accuracy: 0.976562
